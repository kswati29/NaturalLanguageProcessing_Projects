# %% [markdown]
# ## Word Sense Disambiguation Approach using LESK:
# ### **Step 1: Get Input**
#   from Json:
#     1. Get the input: word, sentence and paragraph
#     2. Get all dictionary meanings of the word https://dictionaryapi.com/products/api-collegiate-dictionary
#
# ### Step 2: Perform Preprocessing on
# **(a) the context (sentence/paragraph)
# (b) dictionary data(i.e. POS(fl) and meanings).**
#    1. Preprocessing steps on both context and dictionary data include tokenization, lower case, filter stop words and lemmatize (stemming can be explored).
#    2. Generate a bag(list) of signatures (unique words) of the word meanings with POS.
#    For example, one of the meaning for the word 'firm' is:
#            POS & Meaning: 'fl': 'noun', 'meaning': 'the name or title under which a company transacts business'
#            Generate Signature: ['noun', 'name', 'title', 'company', 'transacts', 'business']
#    3. Genetate a bag of signature for context with POS(tag the word based on context).
#    For example, for the word 'firm', the sentence is:
#            Sentence: My job at the firm ended after four weeks.
#            Generate Signature: ['noun', 'job', 'firm', 'ended', 'four', 'week']
#    4. Remove the looked up word from both the bags (in progress)
#
# ### **Step 3: Apply Lesk Algoritm**
#
#    1. Apply Cosine Lesk algorithm based on Cosine similarity.
#    2. Convert the words to ventors and assign counts.
#    3. Compute the cosine similarity.
#   **Cosine similarity** is a metric used to measure how similar the documents (in our case signatures) are irrespective of their size.
#    Mathematically, it measures the cosine of the angle between two vectors projected in a multi-dimensional space.
#    4. Return a dataframe of the ranked order of meanings based on higher score.
#
# ### **Step 4: Generate and export Output in Json file format**
#
# #### Synonyms and example sentences in the dictionary data as an addition in input file to be considered for better scoring results

# %%
# Import relevant libraries
import json

# nltk and pywsd # Libraries used 
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer 
from nltk.stem import PorterStemmer

import re, math
from re import sub
from collections import Counter

import numpy as np
import pandas as pd

# %%
# Takes word meanings and returns its signature with POS.

#dict_data = obj['dictionaryData']
def meaning_signatures(dict_data,lu_word):
    signatures = [] # Stores meaning signatures with POS
    tokenizer = nltk.RegexpTokenizer(r"\w+")

    for i in range(len(dict_data)):

        # 1. Tokenize and remove punctuation
        dict_meaning= tokenizer.tokenize(dict_data[i].get("meaning"))

        # 2. Convert all to lower case
        word_set = [word.lower() for word in dict_meaning]

        # 3. Filter out stop words
        stop_words = stopwords.words('english')
        signature = [w for w in word_set if not w in stop_words]

        # 4. Lemmatize the words
        lmtzr = WordNetLemmatizer()
        lemmatized = [lmtzr.lemmatize(word) for word in signature]
        lemmatized= [dict_data[i].get("fl")] + lemmatized #add POS label to the list
        #signatures.append(lemmatized)

        # 5. Stemmer
        ps = PorterStemmer()
        stemmed = [ps.stem(word) for word in lemmatized]
        
        # 6. Remove the look up word if present in meaning
        stemmed[:] = [x for x in stemmed if lu_word not in x]
        # Add stemmed meanings to a list
        signatures.append(stemmed)
        
        
    return (signatures)    

#meaning_signatures(dict_data, word)

# %%
# Takes a paragraph and returns the signature.

#paragraph = str(obj['paragraph'])
def para_signature(paragraph, word):
    sent_sig = [] # Stores sentence signature with POS

    # 1. Tokenize and remove punctuation
    tokenizer = nltk.RegexpTokenizer(r"\w+")
    new_words = tokenizer.tokenize(paragraph)
    
    # For POS Tagging
    def find_pos(new_words):
        pt = nltk.pos_tag(new_words)
        pos1 = "None"
        for i in pt:
            if i[0]== word:
                pos1 = (i[1])
            else:
                continue
        return pos1

    def add_pos(pos_value):
        # make a dictionary of possible tags (in progress)
        pos_tag = {'verb':['VB','VBD','VBG','VBN','VBP','VBZ'], 
                   'noun': ['NN','NNS','NNP'], 
                   'adjective': ['JJ','JJR','JJS'],
                   'adverb':['RB', 'RBR', 'RBS'],
                   'None':['None','']} # "masculine noun",

        for ele in pos_tag:
            for i in pos_tag[ele]:
                if i == pos:
                    return ele
                else:
                    continue

    

    # 2. POS Tagging
    pos = find_pos(new_words)
    pos_to_list = [add_pos(pos)]

    # 3. Convert all to lower case
    words = [word.lower() for word in new_words]

    # 4. Filter out stop words
    stop_words = stopwords.words('english')
    words_rem = [w for w in words if not w in stop_words]

    # 4. Lemmatize the words
    lmtzr = WordNetLemmatizer()
    lemmatized = [lmtzr.lemmatize(word) for word in words_rem]
    lemmatized= pos_to_list + lemmatized   #add POS label to the list
    #sent_sig = lemmatized
    
    # 5. Stemmer
    ps = PorterStemmer()
    stemmed = [ps.stem(word) for word in lemmatized]
    sent_sig = stemmed
    
    return sent_sig

# para_signature(paragraph,word)

# %% [markdown]
# Cosine similarity calculates similarity by measuring the cosine of angle between two vectors.
# https://medium.com/@adriensieg/text-similarities-da019229c894

# %%
def get_cosine(vec1, vec2):
        intersection = set(vec1.keys()) & set(vec2.keys())
        numerator = sum([vec1[x] * vec2[x] for x in intersection])

        sum1 = sum([vec1[x]**2 for x in vec1.keys()])
        sum2 = sum([vec2[x]**2 for x in vec2.keys()])
        denominator = math.sqrt(sum1) * math.sqrt(sum2)

        if not denominator:
            return 0.0
        else:
            return float(numerator) / denominator

# Compare sentence signature with each meaning signature and compute scores 

def df_ranked_scores(signatures,sent_sig,dict_data):
    # 1. Find scores
    scores = []
    for i in signatures:
        vector1 = Counter(sent_sig)
        vector2 = Counter(i)
        cosine = get_cosine(vector1, vector2)
        scores.append(cosine)

    # 2. Extract meaning id and meaning from the input Json
    meaning_ids= [] # meaning ids
    meanings = [] # meanings
    isteacher = [] # Teacher score
    for i in range(len(dict_data)):
        meaning_id = dict_data[i].get("id")
        w_meanings = dict_data[i].get("meaning")
        isteacher_score = dict_data[i].get("isTeacher")
        meaning_ids.append(meaning_id)
        meanings.append(w_meanings)
        isteacher.append(isteacher_score)

    # 3. Generate a dataframe of id, meaning and score
    zipped = list(zip(meaning_ids,meanings, scores,isteacher))
    features = sorted(zipped, key = lambda x: x[2], reverse = True)
    import pandas as pd 
    ranked_meanings = pd.DataFrame(features, columns = ['id', 'meaning','score','isTeacher'])

    return ranked_meanings
#ranked_meanings
#df_ranked_scores(meaning_signatures(dict_data),sent_signature(sentence,word),dict_data)

# Perform Lesk
def cos_lesk(word, paragraph, dict_data):
    p_sig = para_signature(paragraph,word)
    m_sig = meaning_signatures(dict_data,word)
    ranking = df_ranked_scores(m_sig,p_sig,dict_data)
    return ranking

# %% [markdown]
# ## Perform Lesk on Data

# %%
def extract_ids(dicdata):
    ids = []
    for i in dict_data:
        mea_id = i['id']
        ids.append(mea_id)
    return ids

def extract_meanings(dicdata):
    meaning_list = []
    for i in dict_data:
        meaning = i['meaning'] 
        meaning_list.append(meaning)
    return meaning_list

def extract_pos_meanings(dicdata):
    pos_meaning = []
    for i in dict_data:
        pos = i['fl']
        meaning = i['meaning'] 
        pos_mea = pos + ' '+ meaning # POS + meaning
        pos_meaning.append(pos_mea)
    return pos_meaning

def extract_isteacher(dicdata):
    isteacher = []
    for i in dict_data:
        is_tea = i['isTeacher']
        isteacher.append(is_tea)
    return isteacher

# %% [markdown]
# ### Data with 600 words
# 1. delimiter missing before new words
# 2. issue with word so removed:
#     1. 138/139 immobile
#     2. 290/291 abstruse
#     3. 585/586 assuage

# %%
# Load Data and store
# Consideration: If score = 0 and isTeacher = 0 then accuracy score = 0
jsonfile= open('data_600.json','r',encoding='utf8') 
data= jsonfile.read() 

# Parse and Extract word, paragraph, pos and meanings
obj = json.loads(data)

data = obj['data']
print("Total words: ",len(data)) # Total # of words
count=0
# Store accuracy and MRR in blank lists
acc_score=[] 
mrr_score = []

# Parse data and find best meaning
for each_word_data in data:
    word = each_word_data['word']
    paragraph = each_word_data['paragraph']
    dict_data = each_word_data['dictionaryData']
    #for i in dict_data:
        #ids = extract_ids(dict_data)
        #meanings = extract_meanings(dict_data)
        #pos_meanings = extract_pos_meanings(dict_data)
        #isteacher = extract_isteacher(dict_data)
        
    print("\n\nLookup word: ",word)    
    ranked_meanings= cos_lesk(word, paragraph, dict_data)
    print(ranked_meanings)
    
    ai_response = ranked_meanings.iloc[0]
    count +=1
    print(count)
    
    # Find accuracy
    if (ranked_meanings.iloc[0]['isTeacher'] ==1) & (ranked_meanings.iloc[0]['score'] !=0): #Consideration: If score = 0 and isTeacher = 0 then accuracy score = 0
        acc_score.append(1)
    else:
        acc_score.append(0)
        
        
    # Find MRR score
    istea_index = ranked_meanings[ranked_meanings['isTeacher']==1].index[0]+1
    pred_rank =1/istea_index
    mrr_score.append(pred_rank)

# Return Accuracy and MRR    
#print(acc_score)
avg = sum(acc_score)/len(acc_score)
print("The accuracy score is ", round(avg,4))    


mrr = np.sum(mrr_score)/ len(mrr_score)
print("The MRR is ", round(mrr,4))
# Out:
# Total words:  600
#
#
# Lookup word:  circumvent
#      id                                            meaning  score  isTeacher
# 0  3230  to avoid being stopped by (something, such as ...    0.0          1
# 1
#
#
# Lookup word:  addict
#      id                                            meaning     score  \
# 0  3401  a person who is not able to stop taking drugs ...  0.071919
# 1  5884  one exhibiting a compulsive, chronic, physiolo...  0.046065
# 2  5885                    to cause addiction in (someone)  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 2
#
#
# Lookup word:  frustrated
#      id                                            meaning     score  \
# 0  5886  feeling, showing, or characterized by frustrat...  0.097590
# 1  5887                   to balk or defeat in an endeavor  0.054554
#
#    isTeacher
# 0        1.0
# 1        NaN
# 3
#
#
# Lookup word:  manslaughter
#      id                                            meaning     score  \
# 0  2554  the crime of killing a person without intendin...  0.047458
#
#    isTeacher
# 0          1
# 4
#
#
# Lookup word:  bludgeoned
#      id                                  meaning     score  isTeacher
# 0  5697                 to hit with heavy impact  0.044721        NaN
# 1  1080  to hit (someone or something) very hard  0.040000        1.0
# 5
#
#
# Lookup word:  envisioned
#      id                                            meaning     score  \
# 0  5819                              to picture to oneself  0.059235
# 1  2341  to think of (something that you believe might ...  0.056911
#
#    isTeacher
# 0        NaN
# 1        1.0
# 6
#
#
# Lookup word:  bucket
#      id                                            meaning     score  \
# 0  5895  of, relating to, or possessing working-class v...  0.063246
# 1  5896                        an old and dilapidated ship  0.044721
# 2  5891  a list of things that one has not done before ...  0.033806
# 3  5897  the quantity of fluid that falls in one spheri...  0.033806
# 4  5888  a typically cylindrical vessel for catching, h...  0.029814
# 5  5893  a saloon in which liquor was formerly sold fro...  0.029814
# 6  5892  a low, separate, usually contoured seat for on...  0.028284
# 7  5890  a chain of persons acting to put out a fire by...  0.025820
# 8  5889                         to draw or lift in buckets  0.000000
# 9  5894                               to rain very heavily  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        1.0
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 7
#
#
# Lookup word:  acquitted
#      id                                            meaning     score  \
# 0  2482    to decide that someone is not guilty of a crime  0.103975
# 1  5898  to discharge completely (as from an accusation...  0.051988
#
#    isTeacher
# 0        1.0
# 1        NaN
# 8
#
#
# Lookup word:  allegation
#      id                                            meaning     score  \
# 0  5857                      the act of alleging something  0.408248
# 1  2577  a statement saying that someone has done somet...  0.144338
#
#    isTeacher
# 0        NaN
# 1        1.0
# 9
#
#
# Lookup word:  primed
#      id                                            meaning     score  \
# 0  5900                                         fill, load  0.059235
# 1  2579  to make (someone) ready to do something : prepare  0.041885
#
#    isTeacher
# 0        NaN
# 1        1.0
# 10
#
#
# Lookup word:  laden
#      id                                            meaning     score  \
# 0  5901                          carrying a load or burden  0.051299
# 1  5903            to put a load or burden on or in : load  0.038778
# 2  2580  loaded heavily with something : having or carr...  0.027420
# 3  5902                                               lade  0.000000
# 4  5904        Osama 1957—2011 Saudi-born terrorist leader  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 4        NaN
# 11
#
#
# Lookup word:  rhetoric
#      id                                            meaning     score  \
# 0  5905  the art of speaking or writing effectively: su...  0.137649
# 1  5906        of, relating to, or concerned with rhetoric  0.051299
#
#    isTeacher
# 0        1.0
# 1        NaN
# 12
#
#
# Lookup word:  essential
#      id                                            meaning    score  isTeacher
# 0  5907  of, relating to, or constituting essence : inh...  0.04969        NaN
# 1  5908                                    something basic  0.00000        1.0
# 2  5909  any of various amino acids that are required f...  0.00000        NaN
# 3  5910  any of a class of volatile oils that give plan...  0.00000        NaN
# 13
#
#
# Lookup word:  steeped
#      id                                            meaning     score  \
# 0  2600  to put (something) in a liquid for a period of...  0.090722
# 1  5913  to make (someone) know and understand a lot ab...  0.070273
# 2  2601  a way of thinking, behaving, or doing somethin...  0.059391
# 3  5912                      having many traditional parts  0.055556
# 4  5911  to soak in a liquid at a temperature under the...  0.035136
#
#    isTeacher
# 0        0.0
# 1        1.0
# 2        NaN
# 3        NaN
# 4        NaN
# 14
#
#
# Lookup word:  embolden
#      id                                            meaning     score  \
# 0  2486  to make (someone) more confident—usually used ...  0.090722
# 1  5914  to impart boldness or courage to : to instill ...  0.027778
#
#    isTeacher
# 0        1.0
# 1        NaN
# 15
#
#
# Lookup word:  from scratch
#      id                                            meaning     score  \
# 0  5925  a mark or injury produced by scratching; also ...  0.037905
# 1  5926  to begin from a point at which nothing has bee...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 16
#
#
# Lookup word:  distinguishing
#      id                                            meaning     score  \
# 0  3459  to notice or recognize a difference between pe...  0.055048
# 1  5928  quality or characteristic that identifies a th...  0.044947
# 2  5927    to perceive a difference in : mentally separate  0.000000
#
#    isTeacher
# 0        1.0
# 1        1.0
# 2        NaN
# 17
#
#
# Lookup word:  point-blank
#      id                                            meaning  score  isTeacher
# 0  3725                         from a very close distance    0.0        1.0
# 1  5929  marked by no appreciable drop below initial ho...    0.0        NaN
# 18
#
#
# Lookup word:  barricade
#      id                                            meaning     score  \
# 0  2422  a temporary wall, fence, or similar structure ...  0.034503
# 1  2423  to block (something) so that people or things ...  0.000000
#
#    isTeacher
# 0          1
# 1          1
# 19
#
#
# Lookup word:  parody
#      id                                            meaning     score  \
# 0  5932  representation of oneself or itself that has t...  0.094916
# 1  5931                             to compose a parody on  0.067116
# 2  2559  a piece of writing, music, etc., that imitates...  0.032241
# 3  5930  a literary or musical work in which the style ...  0.031068
# 4  2560  to imitate (someone or something) in an amusin...  0.000000
# 5  2561                                 yourself or itself  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 4        NaN
# 5        NaN
# 20
#
#
# Lookup word:  copious
#      id                         meaning     score  isTeacher
# 0  2558  very large in amount or number  0.116248        1.0
# 1  5933   yielding something abundantly  0.058124        NaN
# 21
#
#
# Lookup word:  zeal
#      id                                            meaning     score  \
# 0  5934  eagerness and ardent interest in pursuit of so...  0.087875
# 1  3319  a strong feeling of interest and enthusiasm th...  0.073521
# 2  5935                                   great enthusiasm  0.067116
# 3  3320                     of or relating to missionaries  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 3        NaN
# 22
#
#
# Lookup word:  convictions
#      id                                            meaning     score  \
# 0  5937       the courage to do what one believes is right  0.094809
# 1  2575  the act of proving that a person is guilty of ...  0.074953
# 2  5936  the act or process of finding a person guilty ...  0.067040
# 3  2576  the ability to do something that you know is d...  0.043274
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 3        0.0
# 23
#
#
# Lookup word:  resentments
#      id                                            meaning     score  \
# 0  5938  a feeling of indignant displeasure or persiste...  0.033501
#
#    isTeacher
# 0          1
# 24
#
#
# Lookup word:  constitutes
#      id                 meaning     score  isTeacher
# 0  5944  make up, form, compose  0.047891          1
# 25
#
#
# Lookup word:  befuddled
#      id                                         meaning     score  isTeacher
# 0  5946   to muddle or stupefy with or as if with drink  0.109109        NaN
# 1  5945  utterly confused or puzzled : deeply perplexed  0.000000        1.0
# 2  2502         unable to think clearly : very confused  0.000000        0.0
# 26
#
#
# Lookup word:  damning
#      id                                            meaning     score  \
# 0  5947                                 bringing damnation  0.055300
# 1  5949  causing or leading to one's own condemnation o...  0.039103
# 2  5948  to condemn to a punishment or fate; especially...  0.000000
# 3  3476  —used to show that you are angry or annoyed at...  0.000000
# 4  3477                                 yourself or itself  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 3        NaN
# 4        NaN
# 27
#
#
# Lookup word:  attributed
#      id                                       meaning     score  isTeacher
# 0  5950  to explain (something) by indicating a cause  0.111803          1
# 28
#
#
# Lookup word:  hysteria
#      id                                            meaning     score  \
# 0  3324  a state in which your emotions (such as fear) ...  0.088388
# 1  5951  a psychoneurosis marked by emotional excitabil...  0.075378
# 2  5952  a psychoneurosis in which bodily symptoms (suc...  0.060634
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 29
#
#
# Lookup word:  misapprehension
#      id                                            meaning     score  \
# 0  3478  an incorrect understanding of something : a wr...  0.083333
# 1  3479                                         to do work  0.000000
# 2  5953               to apprehend wrongly : misunderstand  0.000000
# 3  5954  to continue to believe something that is not true  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 3        NaN
# 30
#
#
# Lookup word:  pious
#      id                                            meaning     score  \
# 0  2632  deeply religious : devoted to a particular rel...  0.129099
# 1  5955  marked by or showing reverence for deity and d...  0.111803
# 2  2633  a desire for something to happen or be done : ...  0.000000
# 3  5956  something that is hoped for but will probably ...  0.000000
#
#    isTeacher
# 0        0.0
# 1        NaN
# 2        1.0
# 3        NaN
# 31
#
#
# Lookup word:  truants
#      id                                            meaning     score  \
# 0  2739     a student who misses school without permission  0.193649
# 1  5961  one who shirks duty; especially : one who stay...  0.182574
# 2  5960  to idle away time especially while playing truant  0.059761
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 32
#
#
# Lookup word:  swagger
#      id                                            meaning     score  \
# 0  5963  an arrogantly self-confident way of walking : ...  0.153093
# 1  5962  to conduct oneself in an arrogant or supercili...  0.120096
# 2  2743  a way of walking or behaving that shows you ha...  0.109109
# 3  2744  to walk in a very confident way : to walk with...  0.109109
# 4  5965  a short light stick usually covered with leath...  0.037268
# 5  5964             marked by elegance or showiness : posh  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 4        NaN
# 5        NaN
# 33
#
#
# Lookup word:  jostled
#      id                                            meaning     score  \
# 0  2503  to push against (someone) while moving forward...  0.141264
# 1  5966               to come in contact or into collision  0.078087
#
#    isTeacher
# 0        1.0
# 1        NaN
# 34
#
#
# Lookup word:  incongruously
#      id                                            meaning  score  isTeacher
# 0  2738  strange because of not agreeing with what is u...    0.0        1.0
# 1  5967                         lacking congruity: such as    0.0        NaN
# 35
#
#
# Lookup word:  expelled
#      id               meaning     score  isTeacher
# 0  5968  to force out : eject  0.091287          1
# 36
#
#
# Lookup word:  bullied
#      id                                            meaning     score  \
# 0  5969  to treat (someone) in a cruel, insulting, thre...  0.083333
#
#    isTeacher
# 0          1
# 37
#
#
# Lookup word:  poked
#      id                                            meaning     score  \
# 0  5972                                          prod, jab  0.090167
# 1  5973  to look around or search through something —of...  0.055216
# 2  5975  to look around or search through something —of...  0.055216
# 3  5974                          to move along very slowly  0.000000
#
#    isTeacher
# 0        1.0
# 1        1.0
# 2        NaN
# 3        NaN
# 38
#
#
# Lookup word:  complicit
#      id                                            meaning  score  isTeacher
# 0  2468  helping to commit a crime or do wrong in some way    0.0          1
# 39
#
#
# Lookup word:  Corporal
#      id                                            meaning     score  \
# 0  2749  punishment that involves hitting someone : phy...  0.054253
# 1  2750  a person in the U.S. Marines, the Royal Marine...  0.046984
# 2  5977             of, relating to, or affecting the body  0.040689
# 3  5976  a noncommissioned officer ranking in the army ...  0.040689
# 4  5979       the small detachment commanded by a corporal  0.036394
# 5  2748  an officer in the army or marines with a rank ...  0.033223
# 6  5980  an enlisted man in the marine corps ranking ab...  0.025734
# 7  5978  a linen cloth on which the eucharistic element...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 40
#
#
# Lookup word:  inherent
#      id                                            meaning     score  \
# 0  2469  belonging to the basic nature of someone or so...  0.045835
# 1  5981  involved in the constitution or essential char...  0.038348
#
#    isTeacher
# 0        1.0
# 1        NaN
# 41
#
#
# Lookup word:  ghetto
#      id                                            meaning     score  \
# 0  5982  a quarter of a city in which Jews were formerl...  0.110657
# 1  2751  a part of a city in which members of a particu...  0.088273
# 2  5983  of, relating to, being, or characteristic of a...  0.087287
# 3  2752                                           boom box  0.056344
# 4  5984                                          ghettoize  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 3        NaN
# 4        NaN
# 42
#
#
# Lookup word:  decay
#      id                                            meaning     score  \
# 0  5989                A state of rotting or decomposition  0.048795
# 1  5986  rot; specifically : aerobic decomposition of p...  0.034503
# 2  5987  a radioactive nuclear transformation governed ...  0.021296
# 3  5988  to go slowly from a bad condition to a worse c...  0.000000
# 4  5985                           to undergo decomposition  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 43
#
#
# Lookup word:  perils
#      id                                            meaning     score  \
# 0  5992  a danger to Western civilization held to arise...  0.070535
# 1  2756  the possibility that you will be hurt or kille...  0.067767
# 2  5990  exposure to the risk of being injured, destroy...  0.046176
# 3  5991                                to expose to danger  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 3        NaN
# 44
#
#
# Lookup word:  oracle
#      id                                            meaning     score  \
# 0  2757  a person (such as a priestess) through whom a ...  0.099751
# 1  5993  a person (such as a priestess of ancient Greec...  0.086387
# 2  5994  unincorporated settlement north-northeast of T...  0.000000
# 3  5995  Warren (Edward) 1930— American investor and ph...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 3        NaN
# 45
#
#
# Lookup word:  swampy
#      id                                            meaning     score  \
# 0  5997  consisting of, suggestive of, or resembling sw...  0.047458
#
#    isTeacher
# 0          1
# 46
#
#
# Lookup word:  juke
#      id                                            meaning     score  \
# 0  3229             a cheap bar or club that has a jukebox  0.058124
# 1  3228  to make a false movement in order to deceive (...  0.043937
# 2  5999  a small inexpensive establishment for eating, ...  0.036761
# 3  5998           to fake out of position (as in football)  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        1.0
# 3        NaN
# 47
#
#
# Lookup word:  marquees
#      id                                            meaning     score  \
# 0  6001  a large tent set up for an outdoor party, rece...  0.039043
#
#    isTeacher
# 0          1
# 48
#
#
# Lookup word:  loiterers
#      id                                            meaning  score  isTeacher
# 0  2722  to remain in an area when you do not have a pa...    0.0          1
# 49
#
#
# Lookup word:  hovering
#      id                                            meaning     score  \
# 0  2723  to float in the air without moving in any dire...  0.090167
#
#    isTeacher
# 0          1
# 50
#
#
# Lookup word:  infirmity
#      id                                            meaning     score  \
# 0  5671               the quality or state of being infirm  0.103695
# 1  2728  the quality or state of being weak or ill espe...  0.073324
#
#    isTeacher
# 0        NaN
# 1        1.0
# 51
#
#
# Lookup word:  enchanting
#     id                                            meaning     score  isTeacher
# 0  607  to attract and hold the attention of (someone)...  0.125061          1
# 52
#
#
# Lookup word:  evocative
#      id                                            meaning     score  \
# 0  2727  bringing thoughts, memories, or feelings into ...  0.078386
#
#    isTeacher
# 0          1
# 53
#
#
# Lookup word:  shuttered
#      id                                    meaning     score  isTeacher
# 0  2729  having shutters or having closed shutters  0.111803        NaN
# 1  2730          to cover (a window) with shutters  0.091287        1.0
# 54
#
#
# Lookup word:  abstinence
#      id                                            meaning     score  \
# 0  2731  the practice of not doing or having something ...  0.023959
#
#    isTeacher
# 0          1
# 55
#
#
# Lookup word:  circumvent
#      id                                            meaning  score  isTeacher
# 0  3230  to avoid being stopped by (something, such as ...    0.0          1
# 56
#
#
# Lookup word:  integration
#      id                                            meaning     score  \
# 0  1509  to combine (two or more things) to form or cre...  0.074284
# 1  6004  incorporation as equals into society or an org...  0.043675
#
#    isTeacher
# 0          1
# 1          1
# 57
#
#
# Lookup word:  suspension
#      id                                            meaning     score  \
# 0  6014  a method of vehicle suspension that uses press...  0.072548
# 1  6013  a computerized system in automobiles that acti...  0.072548
# 2  6015  a type of suspension (the parts of a vehicle t...  0.052632
# 3  3012  a bridge that is hung from two or more cables ...  0.043355
# 4  6010  the act of suspending : the state or period of...  0.040555
# 5  6011  a bridge that has its roadway suspended from t...  0.033113
# 6  6012  usually three spaced periods used to show the ...  0.029617
# 7  3011  the act of forcing someone to leave a job, pos...  0.025031
# 8  3013                             not dependent: such as  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        1.0
# 8        NaN
# 58
#
#
# Lookup word:  contortion
#      id                                            meaning     score  \
# 0  2767  the act of twisting something into an unusual ...  0.041523
#
#    isTeacher
# 0          1
# 59
#
#
# Lookup word:  compromised
#      id                                            meaning     score  \
# 0  5542          to come to agreement by mutual concession  0.037139
# 1  5541  made vulnerable (as to attack or misuse) by un...  0.000000
#
#    isTeacher
# 0          1
# 1          0
# 60
#
#
# Lookup word:  speculate
#      id                                            meaning     score  \
# 0  2667  to think about something and make guesses abou...  0.026631
#
#    isTeacher
# 0          1
# 61
#
#
# Lookup word:  relentlessly
#      id                                            meaning  score  isTeacher
# 0  2670  continuing without becoming weaker, less sever...    0.0          1
# 62
#
#
# Lookup word:  infractions
#      id                                       meaning     score  isTeacher
# 0  2673  an act that breaks a rule or law : violation  0.073324          1
# 63
#
#
# Lookup word:  baton
#      id                                            meaning     score  \
# 0  6016       cudgel, truncheon; specifically : billy club  0.036662
# 1  6017  city and capital of Louisiana on the Mississip...  0.000000
# 2  6018       to pass job and responsibility on to another  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 64
#
#
# Lookup word:  banter
#      id                                            meaning     score  \
# 0  2691  talk in which people make jokes about each oth...  0.046176
#
#    isTeacher
# 0          1
# 65
#
#
# Lookup word:  vertigo
#      id                                            meaning     score  \
# 0  2793  a feeling of dizziness caused especially by be...  0.091670
# 1  6020  a sensation of motion in which the individual ...  0.073127
# 2  6021  a condition marked by short, recurrent episode...  0.050572
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 66
#
#
# Lookup word:  emancipation
#      id                                            meaning     score  \
# 0  5548                 the act or process of emancipating  0.120386
# 1  5549         the act or process of emancipating oneself  0.107676
# 2  2794  to free (someone) from someone else's control ...  0.000000
# 3  2795                                 yourself or itself  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 67
#
#
# Lookup word:  massacres
#      id                                            meaning     score  \
# 0  2693                 the violent killing of many people  0.107676
# 1  2694  to violently kill (a group of people) : slaughter  0.049147
#
#    isTeacher
# 0        1.0
# 1        NaN
# 68
#
#
# Lookup word:  sharecroppers
#      id                                            meaning     score  \
# 0  3399  a farmer especially in the southern U.S. who r...  0.058396
# 1  6022  a tenant farmer especially in the southern U.S...  0.051333
#
#    isTeacher
# 0        1.0
# 1        NaN
# 69
#
#
# Lookup word:  eerily
#      id                                            meaning     score  \
# 0  6023  in a strange and eerie manner : mysteriously, ...  0.049507
#
#    isTeacher
# 0          1
# 70
#
#
# Lookup word:  lynching
#      id                                            meaning     score  \
# 0  2706  to kill (someone) illegally as punishment for ...  0.049507
# 1  5551  serving or intended to prevent or punish lynching  0.049507
# 2  5550  to put to death (as by hanging) by mob action ...  0.038348
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        0.0
# 71
#
#
# Lookup word:  dangling
#      id                                            meaning  score  isTeacher
# 0  6026  to hang loosely and usually so as to be able t...    0.0        1.0
# 1  6027  to force someone to be in an uncertain positio...    0.0        NaN
# 72
#
#
# Lookup word:  charred
#      id                                            meaning     score  \
# 0  6028  to convert to charcoal or carbon usually by he...  0.091670
# 1  6029                        to work as a cleaning woman  0.060634
#
#    isTeacher
# 0        1.0
# 1        NaN
# 73
#
#
# Lookup word:  resilience
#      id                                            meaning     score  \
# 0  6030  the capability of a strained body to recover i...  0.070014
# 1  2798  the ability to become strong, healthy, or succ...  0.040423
#
#    isTeacher
# 0        NaN
# 1        1.0
# 74
#
#
# Lookup word:  indignation
#      id                                            meaning     score  \
# 0  2709  anger caused by something that is unfair or wrong  0.102062
#
#    isTeacher
# 0          1
# 75
#
#
# Lookup word:  sobriety
#      id                       meaning     score  isTeacher
# 0  2707  the state of not being drunk  0.144338          1
# 76
#
#
# Lookup word:  spindly
#      id                         meaning  score  isTeacher
# 0  2705  long and thin and usually weak    0.0          1
# 77
#
#
# Lookup word:  essential
#      id                                            meaning     score  \
# 0  5908                                    something basic  0.187317
# 1  5907  of, relating to, or constituting essence : inh...  0.072548
# 2  5909  any of various amino acids that are required f...  0.000000
# 3  5910  any of a class of volatile oils that give plan...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 3        NaN
# 78
#
#
# Lookup word:  demeanor
#      id                                            meaning     score  \
# 0  2708  a person's appearance and behavior : the way s...  0.051299
#
#    isTeacher
# 0          1
# 79
#
#
# Lookup word:  casual
#      id                                            meaning     score  \
# 0  6031  subject to, resulting from, or occurring by ch...  0.058222
# 1  6035  of, relating to, or being a restaurant that co...  0.024603
# 2  6034               someone who is not looking carefully  0.000000
# 3  6032                       a casual or migratory worker  0.000000
# 4  6033  a temporary accumulation of water not forming ...  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 4        NaN
# 80
#
#
# Lookup word:  idly
#      id                                   meaning     score  isTeacher
# 0  2801  without much thought, effort, or concern  0.053149        1.0
# 1  2802        not working, active, or being used  0.000000        NaN
# 81
#
#
# Lookup word:  enlightenment
#      id                                            meaning     score  \
# 0  2698  the state of having knowledge or understanding...  0.036108
#
#    isTeacher
# 0          1
# 82
#
#
# Lookup word:  refuge
#      id                                            meaning     score  \
# 0  2803  shelter or protection from danger or trouble —...  0.039253
#
#    isTeacher
# 0          1
# 83
#
#
# Lookup word:  smug
#      id                                            meaning  score  isTeacher
# 0  2661  having or showing the annoying quality of peop...    0.0          1
# 84
#
#
# Lookup word:  lurched
#      id                                      meaning   score  isTeacher
# 0  3140  to make a sudden sideways or forward motion  0.0354          1
# 85
#
#
# Lookup word:  mediocre
#      id        meaning  score  isTeacher
# 0  3141  not very good    0.0          1
# 86
#
#
# Lookup word:  wherewithal
#      id                                            meaning     score  \
# 0  2813  the money, skill, etc., that is needed to get ...  0.065547
#
#    isTeacher
# 0          1
# 87
#
#
# Lookup word:  consumption
#      id                                            meaning     score  \
# 0  6037                    the act or process of consuming  0.058521
# 1  6038  lavish or wasteful spending thought to enhance...  0.041380
#
#    isTeacher
# 0        NaN
# 1        1.0
# 88
#
#
# Lookup word:  empowered
#      id                                            meaning     score  \
# 0  2815                         to give power to (someone)  0.058521
# 1  6040       to give official authority or legal power to  0.047782
# 2  6039  having the knowledge, confidence, means, or ab...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 89
#
#
# Lookup word:  anonymity
#      id                                            meaning     score  \
# 0  2817                        a way of living or existing  0.117041
# 1  6041            the quality or state of being anonymous  0.117041
# 2  2816  the quality or state of being unknown to most ...  0.067574
# 3  2818  something that is put around or on top of anot...  0.035289
# 4  6042            only if one's name will not be revealed  0.000000
# 5  6043  with the understanding that one's name will no...  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 4        NaN
# 5        NaN
# 90
#
#
# Lookup word:  chagrined
#      id                                            meaning     score  \
# 0  2820            frustrated or annoyed : feeling chagrin  0.104685
# 1  6044  to vex or unsettle by disappointing or humilia...  0.052342
#
#    isTeacher
# 0        1.0
# 1        NaN
# 91
#
#
# Lookup word:  eavesdrop
#      id                                        meaning     score  isTeacher
# 0  6045  to listen secretly to what is said in private  0.056344          1
# 92
#
#
# Lookup word:  Delta
#      id                                            meaning     score  \
# 0  2796     the fourth letter of the Greek alphabet—Δ or ƍ  0.047619
# 1  6046  low-lying region in NW Miss., extending eastwa...  0.039841
#
#    isTeacher
# 0        NaN
# 1        1.0
# 93
#
#
# Lookup word:  idealism
#      id                                            meaning     score  \
# 0  6047  the practice of forming ideals or living under...  0.102869
#
#    isTeacher
# 0          1
# 94
#
#
# Lookup word:  distracted
#      id                                            meaning     score  \
# 0  6049  to draw or direct (something, such as someone'...  0.083527
# 1  6048  having one's thoughts or attention drawn away ...  0.059815
#
#    isTeacher
# 0        NaN
# 1        1.0
# 95
#
#
# Lookup word:  winced
#      id                                            meaning     score  \
# 0  4600  to shrink back involuntarily (as from pain) : ...  0.088045
#
#    isTeacher
# 0          1
# 96
#
#
# Lookup word:  impenetrable
#      id                                   meaning     score  isTeacher
# 0  2836         impossible to pass or see through  0.044023        1.0
# 1  6050  incapable of being penetrated or pierced  0.044023        NaN
# 97
#
#
# Lookup word:  anomalies
#      id                                            meaning     score  \
# 0  2835  something that is unusual or unexpected : some...  0.093386
#
#    isTeacher
# 0          1
# 98
#
#
# Lookup word:  utilitarian
#      id                                            meaning     score  \
# 0  2837  made to be useful rather than to be decorative...  0.058926
#
#    isTeacher
# 0          1
# 99
#
#
# Lookup word:  flammable
#      id                                            meaning     score  \
# 0  3402  capable of being set on fire and of burning qu...  0.183726
# 1  6053  capable of being easily ignited and of burning...  0.137795
#
#    isTeacher
# 0        1.0
# 1        NaN
# 100
#
#
# Lookup word:  malicious
#      id                                            meaning     score  \
# 0  2849  having or showing a desire to cause harm to an...  0.060302
#
#    isTeacher
# 0          1
# 101
#
#
# Lookup word:  jarring
#      id                                            meaning     score  \
# 0  6055  to have a harshly disagreeable or disconcertin...  0.108465
# 1  2850  to have a harsh or unpleasant effect on someon...  0.091670
# 2  6054  having a harshly concussive, disagreeable, or ...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 102
#
#
# Lookup word:  immense
#      id                                            meaning     score  \
# 0  6056  marked by greatness especially in size or degr...  0.044992
#
#    isTeacher
# 0          1
# 103
#
#
# Lookup word:  escorting
#      id                                            meaning     score  \
# 0  6057                          to accompany as an escort  0.365148
# 1  3422  to go with (someone or something) to give prot...  0.119523
#
#    isTeacher
# 0        NaN
# 1        1.0
# 104
#
#
# Lookup word:  prophet
#      id                                            meaning     score  \
# 0  6059       someone who says that bad things will happen  0.084667
# 1  6058  one who utters divinely inspired revelations: ...  0.084667
# 2  6060  —used as another name for Muhammad, the founde...  0.039193
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 105
#
#
# Lookup word:  dangling
#      id                                            meaning     score  \
# 0  6026  to hang loosely and usually so as to be able t...  0.078386
# 1  6027  to force someone to be in an uncertain positio...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 106
#
#
# Lookup word:  dispatched
#      id                                            meaning     score  \
# 0  6061  to send off or away with promptness or speed; ...  0.029013
# 1  4722  to send away promptly or rapidly to a particul...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 107
#
#
# Lookup word:  deposed
#      id                                         meaning     score  isTeacher
# 0  3257    to remove (someone) from a powerful position  0.086066        1.0
# 1  6062  to remove from a throne or other high position  0.043033        NaN
# 108
#
#
# Lookup word:  corruption
#      id                                            meaning     score  \
# 0  6063  dishonest or illegal behavior especially by po...  0.055556
# 1  6065     opposing, discouraging or punishing corruption  0.043033
# 2  6064  the effect of an attainder which bars a person...  0.029013
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 109
#
#
# Lookup word:  allegation
#      id                                            meaning     score  \
# 0  5857                      the act of alleging something  0.096225
# 1  2577  a statement saying that someone has done somet...  0.034021
#
#    isTeacher
# 0        NaN
# 1        1.0
# 110
#
#
# Lookup word:  embezzling
#      id                                            meaning     score  \
# 0  2853     to steal money that you have been trusted with  0.119523
# 1  6066  to appropriate (something, such as property en...  0.034503
#
#    isTeacher
# 0        1.0
# 1        NaN
# 111
#
#
# Lookup word:  indicted
#      id                                            meaning     score  \
# 0  2852  to formally decide that someone should be put ...  0.075593
# 1  6067  to charge with a crime by the finding or prese...  0.033150
#
#    isTeacher
# 0          0
# 1          1
# 112
#
#
# Lookup word:  provoke
#      id                                            meaning  score  isTeacher
# 0  6075  to call forth (a feeling, an action, etc.) : e...    0.0          1
# 113
#
#
# Lookup word:  integration
#      id                                            meaning     score  \
# 0  1509  to combine (two or more things) to form or cre...  0.028571
# 1  6004  incorporation as equals into society or an org...  0.025198
#
#    isTeacher
# 0          1
# 1          1
# 114
#
#
# Lookup word:  nostalgia
#      id                                            meaning     score  \
# 0  3423  pleasure and sadness that is caused by remembe...  0.031944
#
#    isTeacher
# 0          1
# 115
#
#
# Lookup word:  integration
#      id                                            meaning     score  \
# 0  6004  incorporation as equals into society or an org...  0.033672
# 1  1509  to combine (two or more things) to form or cre...  0.000000
#
#    isTeacher
# 0          1
# 1          1
# 116
#
#
# Lookup word:  deceptively
#      id                                            meaning  score  isTeacher
# 0  6076  tending or having power to cause someone to ac...    0.0          1
# 117
#
#
# Lookup word:  eagerness
#      id                                            meaning  score  isTeacher
# 0  2865  very excited and interested : feeling a strong...    0.0        1.0
# 1  6077  marked by enthusiastic or impatient desire or ...    0.0        NaN
# 118
#
#
# Lookup word:  evicted
#      id                                            meaning     score  \
# 0  2877                to force (someone) to leave a place  0.051299
# 1  6078  to recover (property) from a person by legal p...  0.046829
#
#    isTeacher
# 0        1.0
# 1        NaN
# 119
#
#
# Lookup word:  reluctant
#      id                                            meaning     score  \
# 0  6079  feeling or showing aversion, hesitation, or un...  0.100504
# 1  3984  feeling or showing doubt about doing something...  0.052705
#
#    isTeacher
# 0        NaN
# 1        1.0
# 120
#
#
# Lookup word:  sagged
#      id                                            meaning     score  \
# 0  6080  to droop, sink, or settle from or as if from p...  0.062994
#
#    isTeacher
# 0          1
# 121
#
#
# Lookup word:  snickered
#      id                                            meaning     score  \
# 0  6081  to laugh in a covert or partly suppressed mann...  0.133631
#
#    isTeacher
# 0          1
# 122
#
#
# Lookup word:  rueful
#      id                                       meaning     score  isTeacher
# 0  2880  showing or feeling regret for something done  0.157135          1
# 123
#
#
# Lookup word:  grotesque
#      id                                            meaning     score  \
# 0  6086  of, relating to, or having the characteristics...  0.062500
# 1  6085  a style of decorative art characterized by fan...  0.054554
# 2  3790  very strange or ugly in a way that is not norm...  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 124
#
#
# Lookup word:  compromised
#      id                                            meaning     score  \
# 0  5541  made vulnerable (as to attack or misuse) by un...  0.083333
# 1  5542          to come to agreement by mutual concession  0.055902
#
#    isTeacher
# 0          0
# 1          1
# 125
#
#
# Lookup word:  endorse
#      id                                            meaning     score  \
# 0  6091  to write on the back of; especially : to sign ...  0.097765
# 1  3637  to publicly or officially say that you support...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 126
#
#
# Lookup word:  dignity
#      id                                            meaning     score  \
# 0  6093  formal reserve or seriousness of manner, appea...  0.039193
# 1  2888  a way of appearing or behaving that suggests s...  0.036662
# 2  6094  suitable for someone who is considered less im...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 127
#
#
# Lookup word:  veracity
#      id                                   meaning     score  isTeacher
# 0  2882                         truth or accuracy  0.123091        1.0
# 1  6095  conformity with truth or fact : accuracy  0.095346        NaN
# 128
#
#
# Lookup word:  studious
#      id                               meaning    score  isTeacher
# 0  6096  assiduous in the pursuit of learning  0.06742          1
# 129
#
#
# Lookup word:  estranged
#      id                                            meaning     score  \
# 0  2885  to cause someone to be no longer friendly or c...  0.048650
# 1  6101        a husband who no longer lives with his wife  0.039223
# 2  6102        a wife who no longer lives with her husband  0.039223
# 3  6099  to arouse especially mutual enmity or indiffer...  0.025318
# 4  6098  having lost former closeness and affection : i...  0.024325
# 5  6100       a married couple who no longer live together  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 130
#
#
# Lookup word:  plundered
#      id                                            meaning     score  \
# 0  6103  to take the goods of by force (as in war) : pi...  0.122271
#
#    isTeacher
# 0          1
# 131
#
#
# Lookup word:  amulets
#      id                                            meaning     score  \
# 0  6104  a charm (such as an ornament) often inscribed ...  0.057639
# 1  2886  a small object worn to protect the person wear...  0.027842
#
#    isTeacher
# 0        NaN
# 1        1.0
# 132
#
#
# Lookup word:  graffiti
#      id                                            meaning     score  \
# 0  6105  usually unauthorized writing or drawing on a p...  0.040757
# 1  6107  an inscription or drawing made on some public ...  0.029907
# 2  6106      to draw graffiti on : to deface with graffiti  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 133
#
#
# Lookup word:  exhortations
#      id                                            meaning     score  \
# 0  6019          language intended to incite and encourage  0.046625
# 1  2674  to try to influence (someone) by words or advi...  0.000000
#
#    isTeacher
# 0          1
# 1          1
# 134
#
#
# Lookup word:  resolutions
#      id                                            meaning     score  \
# 0  6112  a resolution passed by both houses of a legisl...  0.104257
# 1  6113  a resolution passed by both houses of a legisl...  0.083592
# 2  6111           the act or process of resolving: such as  0.052129
# 3  2891  the act of finding an answer or solution to a ...  0.028916
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        NaN
# 3        1.0
# 135
#
#
# Lookup word:  subsequently
#      id                                            meaning     score  \
# 0  6114                      at a later or subsequent time  0.156386
# 1  3525  happening or coming after something else —ofte...  0.085126
#
#    isTeacher
# 0        NaN
# 1        1.0
# 136
#
#
# Lookup word:  inclination
#      id                                            meaning     score  \
# 0  6115  a tendency to a particular aspect, state, char...  0.039406
# 1  4009  a feeling of wanting to do something : a tende...  0.036860
#
#    isTeacher
# 0        NaN
# 1        1.0
# 137
#
#
# Lookup word:  sneered
#      id                                            meaning     score  \
# 0  6122  to smile or laugh with facial contortions that...  0.088388
# 1  1267  to smile or laugh at someone or something with...  0.072169
#
#    isTeacher
# 0        NaN
# 1        1.0
# 138
#
#
# Lookup word:  stiffened
#      id                                            meaning     score  \
# 0  2890  to stop moving and become completely still esp...  0.072548
#
#    isTeacher
# 0          1
# 139
#
#
# Lookup word:  diminutive
#      id                                            meaning  score  isTeacher
# 0  2901                                         very small    0.0        1.0
# 1  2902  a word or suffix that indicates that something...    0.0        NaN
# 140
#
#
# Lookup word:  gesturing
#      id                                            meaning     score  \
# 0  6128                                  to make a gesture  0.204124
# 1  6708  direct or invite (someone) to move somewhere s...  0.117851
#
#    isTeacher
# 0          1
# 1          1
# 141
#
#
# Lookup word:  Occupied
#      id                                 meaning     score  isTeacher
# 0  6129  to engage the attention or energies of  0.218218        1.0
# 1  6130                   lived in by the owner  0.000000        NaN
# 142
#
#
# Lookup word:  resented
#      id                                      meaning     score  isTeacher
# 0  6131  to feel or express annoyance or ill will at  0.111803          1
# 143
#
#
# Lookup word:  revising
#      id                                            meaning  score  isTeacher
# 0  6132  to look over again in order to correct or improve    0.0          1
# 144
#
#
# Lookup word:  aggressive
#      id                                            meaning     score  \
# 0  3833  ready and willing to fight, argue, etc. : feel...  0.111111
#
#    isTeacher
# 0          1
# 145
#
#
# Lookup word:  tedious
#      id                      meaning     score  isTeacher
# 0  2904  boring and too slow or long  0.082199          1
# 146
#
#
# Lookup word:  tilted
#      id                                            meaning     score  \
# 0  6127     move or cause to move into a sloping position.  0.126773
# 1  6125                    to cover or provide with a tilt  0.119523
# 2  6124                    to cause to have an inclination  0.069007
# 3  6126  to attack (someone or something) in writing or...  0.048795
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 3        NaN
# 147
#
#
# Lookup word:  dumbstruck
#      id                                        meaning  score  isTeacher
# 0  6136                    made silent by astonishment    0.0        1.0
# 1  3836  so shocked or surprised that you cannot speak    0.0        NaN
# 148
#
#
# Lookup word:  riskier
#      id                                   meaning     score  isTeacher
# 0  6137  attended with risk or danger : hazardous  0.075324          1
# 149
#
#
# Lookup word:  intrinsic
#      id                                            meaning     score  \
# 0  4010  belonging to the essential nature of a thing :...  0.072932
# 1  6138  belonging to the essential nature or constitut...  0.068761
# 2  6139  a substance produced by normal gastrointestina...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 150
#
#
# Lookup word:  incredulous
#      id                                            meaning     score  \
# 0  4841                  tending to disbelieve : skeptical  0.081111
# 1  2907  not able or willing to believe something : fee...  0.054074
#
#    isTeacher
# 0        NaN
# 1        1.0
# 151
#
#
# Lookup word:  notorious
#      id                                            meaning     score  \
# 0  6141                              in a notorious manner  0.070535
# 1  6140  generally known and talked of; especially : wi...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 152
#
#
# Lookup word:  crumple
#      id                                            meaning     score  \
# 0  6143              a wrinkle or crease made by crumpling  0.091287
# 1  6142     to press, bend, or crush out of shape : rumple  0.083333
# 2  3748  to press or squeeze (something) so that it is ...  0.072169
# 3  6144  a section of an automobile body designed to ab...  0.000000
# 4  6145  to have one's face show signs that one is abou...  0.000000
# 5  3749  the front part of a vehicle that is designed t...  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 4        NaN
# 5        NaN
# 153
#
#
# Lookup word:  arrhythmic
#      id                                         meaning     score  isTeacher
# 0  6146                    lacking rhythm or regularity  0.081111        1.0
# 1  6147  counteracting or preventing cardiac arrhythmia  0.072548        NaN
# 154
#
#
# Lookup word:  skeptics
#      id                                            meaning     score  \
# 0  6148              an adherent or advocate of skepticism  0.277350
# 1  4011  a person who questions or doubts something (su...  0.065372
#
#    isTeacher
# 0        NaN
# 1        1.0
# 155
#
#
# Lookup word:  involuntary
#      id                                            meaning     score  \
# 0  4922          not made or done willingly or from choice  0.136399
# 1  3041                             not voluntary: such as  0.107833
# ...
# 1  4838  to turn aside especially from the main subject...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 546
#
#
# Lookup word:  replicate
#      id                                            meaning  score  isTeacher
# 0  6914                                  duplicate, repeat    0.0        1.0
# 1  6916  one of several identical experiments, procedur...    0.0        NaN
# 2  6915                                 manifold, repeated    0.0        NaN
# 547
#
#
# Lookup word:  frown
#      id                                            meaning  score  isTeacher
# 0  6780  to contract the brow in displeasure or concent...    0.2        1.0
# 1  6781                       an expression of displeasure    0.0        1.0
# 2  6782                       to disapprove of (something)    0.0        NaN
# 548
#
#
# Lookup word:  desperation
#      id                                            meaning     score  \
# 0  4370  a strong feeling of sadness, fear, and loss of...  0.048002
#
#    isTeacher
# 0          1
# 549
#
#
# Lookup word:  tentatively
#      id                                            meaning     score  \
# 0  6917  with hesitancy or uncertainty : in a tentative...  0.068802
#
#    isTeacher
# 0          1
# 550
#
#
# Lookup word:  captivated
#      id                                    meaning  score  isTeacher
# 0  4585  to attract and win over : charm fascinate    0.0          1
# 551
#
#
# Lookup word:  unassailable
#      id                                            meaning     score  \
# 0  6924  not assailable : not liable to doubt, attack, ...  0.050252
#
#    isTeacher
# 0          1
# 552
#
#
# Lookup word:  dignity
#      id                                            meaning     score  \
# 0  2888  a way of appearing or behaving that suggests s...  0.087039
# 1  6094  suitable for someone who is considered less im...  0.050252
# 2  6093  formal reserve or seriousness of manner, appea...  0.046524
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 553
#
#
# Lookup word:  emancipation
#      id                                            meaning     score  \
# 0  5548                 the act or process of emancipating  0.577350
# 1  5549         the act or process of emancipating oneself  0.516398
# 2  2794  to free (someone) from someone else's control ...  0.000000
# 3  2795                                 yourself or itself  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 554
#
#
# Lookup word:  corruption
#      id                                            meaning     score  \
# 0  6063  dishonest or illegal behavior especially by po...  0.132453
# 1  6065     opposing, discouraging or punishing corruption  0.102598
# 2  6064  the effect of an attainder which bars a person...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 555
#
#
# Lookup word:  incredulous
#      id                                            meaning     score  \
# 0  4841                  tending to disbelieve : skeptical  0.250000
# 1  2907  not able or willing to believe something : fee...  0.166667
#
#    isTeacher
# 0        NaN
# 1        1.0
# 556
#
#
# Lookup word:  solidarity
#      id                                            meaning     score  \
# 0  6264  unity (as of a group or class) that produces o...  0.095346
#
#    isTeacher
# 0          1
# 557
#
#
# Lookup word:  constitutes
#      id                 meaning     score  isTeacher
# 0  5944  make up, form, compose  0.114708          1
# 558
#
#
# Lookup word:  deliberating
#      id                                            meaning     score  \
# 0  6925  to think about or discuss issues and decisions...  0.085126
#
#    isTeacher
# 0          1
# 559
#
#
# Lookup word:  equivocating
#      id                                            meaning  score  isTeacher
# 0  4842  to use unclear language especially with intent...    0.0          1
# 560
#
#
# Lookup word:  anguish
#      id                                   meaning     score  isTeacher
# 0  4040         extreme suffering, grief, or pain  0.205196        1.0
# 1  4843  extreme pain or distress of body or mind  0.187317        NaN
# 561
#
#
# Lookup word:  compelled
#      id                                      meaning     score  isTeacher
# 0  6926  to drive or urge forcefully or irresistibly  0.119523        NaN
# 1  6927           to feel required (to do something)  0.000000        1.0
# 562
#
#
# Lookup word:  vanished
#      id                                 meaning     score  isTeacher
# 0  6928  to pass quickly from sight : disappear  0.119523          1
# 563
#
#
# Lookup word:  Delta
#      id                                            meaning     score  \
# 0  6046  low-lying region in NW Miss., extending eastwa...  0.086874
# 1  2796     the fourth letter of the Greek alphabet—Δ or ƍ  0.051917
#
#    isTeacher
# 0        1.0
# 1        NaN
# 564
#
#
# Lookup word:  forsake
#      id                                            meaning     score  \
# 0  6931             to renounce or turn away from entirely  0.071157
# 1  6933             —used to express surprise or annoyance  0.035578
# 2  6934  —used to make a statement or question more for...  0.025158
# 3  6932  —used to refer to making art for no other reas...  0.025158
# 4  6939      in order to make something simpler and easier  0.000000
# 5  6935  in order to experience again something one did...  0.000000
# 6  6936      in order to make something simpler and easier  0.000000
# 7  6937  because other people think it is the proper th...  0.000000
# 8  6938                           for no particular reason  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 565
#
#
# Lookup word:  crappy
#      id                               meaning  score  isTeacher
# 0  6944  markedly inferior in quality : lousy    0.0          1
# 566
#
#
# Lookup word:  sacred
#      id                                            meaning     score  \
# 0  6950  a baboon (Papio hamadryas) that has a reddish-...  0.105409
# 1  6947  one that is often unreasonably immune from cri...  0.000000
# 2  6945  dedicated or set apart for the service or wors...  0.000000
# 3  6946                                   hamadryas baboon  0.000000
# 4  6948                                             peepul  0.000000
# 5  6949                                     magic mushroom  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 567
#
#
# Lookup word:  contraband
#      id                                            meaning     score  \
# 0  4682  goods or merchandise whose importation, export...  0.055216
#
#    isTeacher
# 0          1
# 568
#
#
# Lookup word:  threshold
#      id                                            meaning     score  \
# 0  6964        the level at which someone experiences pain  0.182574
# 1  6962  the plank, stone, or piece of timber that lies...  0.144338
# 2  6963  at the beginning of something or very close to...  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 569
#
#
# Lookup word:  fleetingly
#      id                       meaning  score  isTeacher
# 0  6965  passing swiftly : transitory    0.0          1
# 570
#
#
# Lookup word:  calligraphic
#      id                                            meaning    score  isTeacher
# 0  6966  artistic, stylized, or elegant handwriting or ...  0.15162          1
# 571
#
#
# Lookup word:  exhort
#      id                                          meaning     score  isTeacher
# 0  6967  to incite by argument or advice : urge strongly  0.068041          1
# 572
#
#
# Lookup word:  diminish
#      id                               meaning     score  isTeacher
# 0  6968  to make less or cause to appear less  0.058926          1
# 573
#
#
# Lookup word:  verdant
#      id                 meaning     score  isTeacher
# 0  6969  green in tint or color  0.057735          1
# 574
#
#
# Lookup word:  teeters
#      id             meaning     score  isTeacher
# 0  4881  to move unsteadily  0.066667          1
# 575
#
#
# Lookup word:  clatters
#      id                                            meaning     score  \
# 0  4882          to make or cause to make a rattling sound  0.040825
# 1  4883  a rattling sound (as of hard bodies striking t...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 576
#
#
# Lookup word:  pushiness
#      id                                            meaning  score  isTeacher
# 0  6970  aggressive often to an objectionable degree : ...    0.0          1
# 577
#
#
# Lookup word:  eviction
#      id                                            meaning     score  \
# 0  6971  to recover (property) from a person by legal p...  0.078567
#
#    isTeacher
# 0          1
# 578
#
#
# Lookup word:  disparity
#      id                                            meaning     score  \
# 0  6333  a noticeable and usually significant differenc...  0.083333
# 1  2049  a noticeable and often unfair difference betwe...  0.077152
#
#    isTeacher
# 0        NaN
# 1        1.0
# 579
#
#
# Lookup word:  nonchalantly
#      id                                            meaning     score  \
# 0  5754  in a nonchalant manner : in a casual way that ...  0.037529
# 1  4395  relaxed and calm in a way that shows that you ...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 580
#
#
# Lookup word:  surmised
#      id                                            meaning     score  \
# 0  6972  to form a notion of from scanty evidence : ima...  0.044856
#
#    isTeacher
# 0          1
# 581
#
#
# Lookup word:  eavesdrop
#      id                                        meaning     score  isTeacher
# 0  6045  to listen secretly to what is said in private  0.053452          1
# 582
#
#
# Lookup word:  disposition
#      id                                    meaning     score  isTeacher
# 0  6975  prevailing tendency, mood, or inclination  0.053452          1
# 583
#
#
# Lookup word:  affidavits
#      id                                            meaning     score  \
# 0  6976  a sworn statement in writing made especially u...  0.047088
#
#    isTeacher
# 0          1
# 584
#
#
# Lookup word:  Mortifying
#      id                                            meaning     score  \
# 0  6978  to subject to severe and vexing embarrassment ...  0.085126
# 1  6977  causing feelings of strong shame or embarrassment  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 585
#
#
# Lookup word:  impressionable
#      id                            meaning     score  isTeacher
# 0  6982  capable of being easily impressed  0.051031          1
# 586
#
#
# Lookup word:  tabula
#      id                                            meaning    score  isTeacher
# 0  6983  the mind in its hypothetical primary blank or ...  0.06455          1
# 587
#
#
# Lookup word:  wrench
#      id                                            meaning     score  \
# 0  6985  a violent twisting or a pull with or as if wit...  0.152894
# 1  6987  a wrench with one fixed and one adjustable jaw...  0.116775
# 2  6984  to move with a violent twist; also : to underg...  0.089893
# 3  6986  an L-shaped hexagonal metal bar either end of ...  0.077850
# 4  6988  a wrench for gripping and turning a cylindrica...  0.056232
# 5  6990  to damage or change (something) in a way that ...  0.044947
# 6  6991  to damage or change (something) in a way that ...  0.044947
# 7  6989  a wrench usually in the form of a bar and remo...  0.042640
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 588
#
#
# Lookup word:  contorting
#      id                       meaning    score  isTeacher
# 0  6992  to twist in a violent manner  0.13484          1
# 589
#
#
# Lookup word:  habitation
#      id                            meaning     score  isTeacher
# 0  6995  the act of inhabiting : occupancy  0.084515          1
# 590
#
#
# Lookup word:  patronizing
#      id                                            meaning     score  \
# 0  2700  to give money or support to (someone or someth...  0.235702
# 1  2699  showing that you believe you are more intellig...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 591
#
#
# Lookup word:  converging
#      id                                            meaning     score  \
# 0  6997  to tend or move toward one point or one anothe...  0.252149
# 1  6998  a lens that causes parallel rays (as of light)...  0.000000
#
#    isTeacher
# 0        1.0
# 1        NaN
# 592
#
#
# Lookup word:  diverging
#      id                                            meaning     score  \
# 0  6999  to move or extend in different directions from...  0.067344
#
#    isTeacher
# 0          1
# 593
#
#
# Lookup word:  juncture
#      id                                            meaning     score  \
# 0  7000  a point of time; especially : one made critica...  0.046225
#
#    isTeacher
# 0          1
# 594
#
#
# Lookup word:  spectacular
#      id                                            meaning     score  \
# 0  7003  ADJECTIVE\n\nbeautiful in a dramatic and eye-c...  0.083992
# 1  7001  of, relating to, or being a spectacle : striki...  0.056344
# 2  7002  something that is spectacular; especially : an...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 595
#
#
# Lookup word:  distracted
#      id                                            meaning     score  \
# 0  6049  to draw or direct (something, such as someone'...  0.043033
# 1  6048  having one's thoughts or attention drawn away ...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 596
#
#
# Lookup word:  alternative
#       id                                            meaning     score  \
# 0   3481  something that can be chosen instead of someth...  0.110506
# 1   6153  a proposition or situation offering a choice b...  0.077267
# 2   6158  a U.S. federal income tax that was originally ...  0.077267
# 3   6161  alternative music that blends elements of conv...  0.073302
# 4   6154                                        alt-country  0.070535
# 5   6155  usable power (such as heat or electricity) tha...  0.040723
# 6   6156  a fuel for internal combustion engines that is...  0.029630
# 7   6157  any of various systems of healing or treating ...  0.028796
# 8   6159  music that is produced by performers who are o...  0.023512
# 9   6160  pop music that has broad appeal but that is pr...  0.019080
# 10  3480                    offering or expressing a choice  0.000000
#
#     isTeacher
# 0         1.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 597
#
#
# Lookup word:  reprimand
#      id                                            meaning     score  \
# 0  4896                         a severe or formal reproof  0.061546
# 1  2463  to speak in an angry and critical way to (some...  0.000000
# 2  4897  to reprove severely and usually formally from ...  0.000000
#
#    isTeacher
# 0        NaN
# 1        1.0
# 2        NaN
# 598
#
#
# Lookup word:  fiddles
#      id                                            meaning     score  \
# 0  7007                                to play on a fiddle  0.071067
# 1  7011    one that plays a supporting or subservient role  0.050252
# 2  7013  to move or handle (something) with the hands o...  0.043519
# 3  7006                                             violin  0.000000
# 4  7012  to spend time in activity that does not have a...  0.000000
# 5  7008                                        double bass  0.000000
# 6  7009                                        double bass  0.000000
# 7  7010                                    to fritter away  0.000000
#
#    isTeacher
# 0        NaN
# 1        NaN
# 2        1.0
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 599
#
#
# Lookup word:  indebted
#      id                                            meaning  score  isTeacher
# 0  7014  owing gratitude or recognition to another : be...    0.0          1
# 600
# The accuracy score is  0.5467
# The MRR is  0.8254

# %%
print("The accuracy score is ", round(avg,4)) 
print("The MRR is ", round(mrr,4))
# Out:
# The accuracy score is  0.5467
# The MRR is  0.8254

# %%
# ranked_meanings.to_json('ranked_meaning_lesk.json')

# %%
ai_response =  ranked_meanings.head(1).to_dict(orient='index')
ai_response
# Out:
# {0: {'id': 7014,
#   'meaning': 'owing gratitude or recognition to another : beholden',
#   'score': 0.0,
#   'isTeacher': 1}}
